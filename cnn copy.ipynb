# %% [markdown]
# ## Importing the Libraries

# %%
import os
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Running pre-processing file
# %run directory.ipynb

# %% [markdown]
# ## Defining Training Images

# %%
img_height = 64
img_width = 64
batch_size = 4
nb_epochs = 10

# %%
TRAINING_DIR = "tmp"

train_datagen = ImageDataGenerator(
                rescale = 1/255.0,
                shear_range=0.2,
                zoom_range=0.2,
                horizontal_flip=False,
                validation_split=0.2)
train_set = train_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training') # set as training data
# Out:
# Found 2728 images belonging to 62 classes.

# %% [markdown]
# ### Plotting some training images

# %%
plt.imshow(train_set)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-df33c7f374ad> in <module>
# ----> 1 plt.imshow(train_set[0])
#
# C:\Python\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2705         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2706         data=None, **kwargs):
# -> 2707     __ret = gca().imshow(
#    2708         X, cmap=cmap, norm=norm, aspect=aspect,
#    2709         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# C:\Python\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1429     def inner(ax, *args, data=None, **kwargs):
#    1430         if data is None:
# -> 1431             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1432
#    1433         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\Python\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5517                               resample=resample, **kwargs)
#    5518
# -> 5519         im.set_data(X)
#    5520         im.set_alpha(alpha)
#    5521         if im.get_clip_path() is None:
#
# C:\Python\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     691         if isinstance(A, PIL.Image.Image):
#     692             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 693         self._A = cbook.safe_masked_invalid(A, copy=True)
#     694
#     695         if (self._A.dtype != np.uint8 and
#
# C:\Python\lib\site-packages\matplotlib\cbook\__init__.py in safe_masked_invalid(x, copy)
#     680
#     681 def safe_masked_invalid(x, copy=False):
# --> 682     x = np.array(x, subok=True, copy=copy)
#     683     if not x.dtype.isnative:
#     684         # If we have already made a copy, do the byteswap in place, else make a
#
# ValueError: could not broadcast input array from shape (4,64,64,3) into shape (4)

# %% [markdown]
# ## Defining Validation Images

# %%
validation_set = train_datagen.flow_from_directory(
    TRAINING_DIR, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation') # set as validation data
# Out:
# Found 682 images belonging to 62 classes.

# %% [markdown]
# ## Designing Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape = (img_height, img_width, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dense(units=62, activation='softmax'),
    #tf.keras.layers.Flatten()
])

# %%
model.compile(optimizer='adam', loss = tf.keras.losses.CategoricalCrossentropy(), metrics= tf.keras.metrics.CategoricalAccuracy())

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 62, 62, 16)        448
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 31, 31, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 29, 29, 32)        4640
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# dense_15 (Dense)             (None, 62)                31806
# =================================================================
# Total params: 1,235,550
# Trainable params: 1,235,550
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fitting on Model

# %%
history = model.fit_generator(
    train_set,
    steps_per_epoch = train_set.samples // batch_size,
    validation_data = validation_set, 
    validation_steps = validation_set.samples // batch_size,
    epochs = nb_epochs)
# Out:
# Epoch 1/10
# 682/682 [==============================] - 30s 44ms/step - loss: 3.0944 - categorical_accuracy: 0.2350 - val_loss: 1.9434 - val_categorical_accuracy: 0.4912
# Epoch 2/10
# 682/682 [==============================] - 30s 44ms/step - loss: 1.1671 - categorical_accuracy: 0.6661 - val_loss: 1.7101 - val_categorical_accuracy: 0.5294
# Epoch 3/10
# 682/682 [==============================] - 29s 43ms/step - loss: 0.7061 - categorical_accuracy: 0.7753 - val_loss: 1.4877 - val_categorical_accuracy: 0.6353
# Epoch 4/10
# 682/682 [==============================] - 30s 44ms/step - loss: 0.4872 - categorical_accuracy: 0.8376 - val_loss: 1.4442 - val_categorical_accuracy: 0.6426
# Epoch 5/10
# 682/682 [==============================] - 29s 43ms/step - loss: 0.3774 - categorical_accuracy: 0.8746 - val_loss: 1.4418 - val_categorical_accuracy: 0.6574
# Epoch 6/10
# 682/682 [==============================] - 30s 44ms/step - loss: 0.2795 - categorical_accuracy: 0.9054 - val_loss: 1.5068 - val_categorical_accuracy: 0.6588
# Epoch 7/10
# 682/682 [==============================] - 28s 42ms/step - loss: 0.2597 - categorical_accuracy: 0.9142 - val_loss: 1.3995 - val_categorical_accuracy: 0.6721
# Epoch 8/10
# 682/682 [==============================] - 28s 41ms/step - loss: 0.2204 - categorical_accuracy: 0.9307 - val_loss: 1.5959 - val_categorical_accuracy: 0.6515
# Epoch 9/10
# 682/682 [==============================] - 28s 41ms/step - loss: 0.2208 - categorical_accuracy: 0.9212 - val_loss: 1.9171 - val_categorical_accuracy: 0.6397
# Epoch 10/10
# 682/682 [==============================] - 28s 41ms/step - loss: 0.1910 - categorical_accuracy: 0.9337 - val_loss: 1.7565 - val_categorical_accuracy: 0.6765

# %% [markdown]
# ## Evaluating on Training Set

# %%
results = model.evaluate(train_set, verbose=0)

# %%
results
# Out:
# [0.09816358238458633, 0.9688416719436646]

# %% [markdown]
# ## Plotting the result

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['categorical_accuracy']
val_acc=history.history['val_categorical_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")


plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')
